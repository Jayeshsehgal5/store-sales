# %%
import numpy as np
import Preprocessing
import Model_creation
import pandas as pd
df=pd.read_csv("storesales_train.csv")

# %%
data=Preprocessing.Preprocessing(df)

# %%
x,y=data.preprocessing()
# Out:
# C:\Users\JAY\anaconda3\lib\site-packages\pandas\core\generic.py:5494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# C:\Users\JAY\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# C:\Users\JAY\Desktop\store sales\Store-Sales-Prediction-main\Preprocessing.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
x
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Item_Fat_Content  Outlet_Size  \
# 0           9.300         0.016047  249.8092                 1            2
# 1           5.920         0.019278   48.2692                 0            2
# 2          17.500         0.016760  141.6180                 1            2
# 3          19.200         0.000000  182.0950                 0            2
# 4           8.930         0.000000   53.8614                 1            3
# ...           ...              ...       ...               ...          ...
# 8518        6.865         0.056783  214.5218                 1            3
# 8519        8.380         0.046982  108.1570                 0            2
# 8520       10.600         0.035186   85.1224                 1            1
# 8521        7.210         0.145221  103.1332                 0            2
# 8522       14.800         0.044878   75.4670                 1            1
#
# ...

# %%
y
# Out:
# 0       8.225540
# 1       6.094524
# 2       7.648392
# 3       6.596300
# 4       6.902446
#           ...
# 8518    7.929625
# 8519    6.308617
# 8520    7.084322
# 8521    7.520558
# 8522    6.640751
# Name: Item_Outlet_Sales, Length: 8523, dtype: float64

# %%
a=Model_creation.model_creation(x,y)

# %%
a.model_creation()
